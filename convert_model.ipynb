# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.python.compiler.tensorrt import trt_convert as trt
from tensorflow.python.saved_model import tag_constants
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
def test_single_image(test_file_path, model, image_class):
    ''' Test a single image to see if the model is properly predicting.
        Image class is either 1 or 0.
        
    Args: 
        test_file_path (str): File path for the image you want to test.
        model (str): Model you want to test.
        image_class: Presumed label for the image you want to test.
        
    Returns:
        Model prediction of single image input.
        
    '''

    test_img = image.load_img(test_file_path, target_size= (64, 64))
    test_tensor = image.img_to_array(test_img)
    test_tensor = test_tensor.reshape(1, 64, 64, 3)
    test_tensor /= 255.

    # Get prediction
    test_pred = model.predict(test_tensor).round()

    # Output
    print('The true class of this image is: ', img_class)
    print('The predicted class of this images is: ', test_pred)

# %%
model = tf.keras.models.load_model("base_model/model_X.h5")
# Out:
# I0000 00:00:1730830075.670045   21073 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2242 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
test_real_img = 'test_data/real_11.jpg'
test_fake_img = 'test_data/fake_14.jpg'

# %%
img_class = 1
test_single_image(test_real_img, model, img_class)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730830083.427849   21864 service.cc:148] XLA service 0x7f2278002750 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730830083.428440   21864 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1650 Ti, Compute Capability 7.5
# 2024-11-06 01:08:03.479740: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1730830083.836589   21864 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# The true class of this image is:  1
# The predicted class of this images is:  [[1.]]
# I0000 00:00:1730830087.013481   21864 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
img_class = 0
test_single_image(test_fake_img, model, img_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# The true class of this image is:  0
# The predicted class of this images is:  [[0.]]

# %%
export_path = 'models/serving/1'
model.export(export_path)
# Out:
# INFO:tensorflow:Assets written to: models/serving/1/assets
# INFO:tensorflow:Assets written to: models/serving/1/assets
# Saved artifact at 'models/serving/1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139790375021632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373099952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373102064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373095376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373097664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373105408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373105760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373107168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373103648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373105056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373107520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373107696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373176592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373099776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373102944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373177296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373106992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373179408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373183808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373180464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373180112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373178176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373180640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373179232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373182048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373181872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373184336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373188208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373183104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373186624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373186096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373189440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373190848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373185040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373184512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373309424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373307488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373308896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373308368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373311008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373313472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373310128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373311536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373315936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373312416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373314352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373317696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373313824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373317168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373320336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373318576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373319632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373321216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373308544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373319280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373319984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373373376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373373024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373374080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373373728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373378128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373374608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373376544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373377600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373376016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373379360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373382528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373380768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373384288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373380592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373383760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373386928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373385872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373382880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373379888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373384640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373382352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373473616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373474672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373474320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373472384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373474848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373478016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373476256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373476432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373477488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373476080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373479248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373482416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373480656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373480832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373480480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373483648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373484352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373485408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373554656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373554304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373485760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373553248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373485936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373557120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373556064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373556592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373555888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373561520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373559760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373559936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373563280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373559584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373562752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373566096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373563456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373566976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373558176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373565040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373565744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373552544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373567152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373653664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373654016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373654896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373653840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373657008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373655248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373655424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373656480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373655072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373658240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373658944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373660000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373663344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373662816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373664224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373664400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373661936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373658592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373666160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373765888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373661408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373768880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373769936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373769584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373767648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373770112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373770816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373771872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373772928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373771344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373774688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373777856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373776096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373776272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373779616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373775920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373779088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373780496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373780672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373817152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373816800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373817328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373816096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373819792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373816448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373818208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373819264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373817680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373821024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373824192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373822432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373822608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373825952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373822256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373825424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373828592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373826832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373829120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373821552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373828944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373827888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373816272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373828768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373949104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373950336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373949280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373952448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373950688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373950864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373951920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373950512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373956848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373955088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373955264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373958608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373954912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373958080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373958784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373959840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373995968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373996496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373961072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373995440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373956320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373998784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374003184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373999840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373999488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790373997552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374000016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374003536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374004768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374000720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374002832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374007232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374003712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374008992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374005120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374008464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374010048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348503872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348503520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348504048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348502816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348502112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790374007584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790375748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348508800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348506160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348517072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348514784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790348516192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790385432000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790385436928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790385437808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790385441856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139790385442736: TensorSpec(shape=(), dtype=tf.resource, name=None)
